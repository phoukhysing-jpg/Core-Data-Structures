# %%
quiz_data = {
    "Do you love me?" : "Yes",
    
}
score = 0
print("--- Welcome to the Quiz! ---")
print("Your answer is Yes or No")
for question, correct_answer in quiz_data.items():
    user_answer = input(f"{question} ")    
    if user_answer.strip().lower() == correct_answer.lower():
        print("Correct! ")
        score += 1
    else:
        print(f"Wrong. The correct answer was {correct_answer}.")
    print("-" * 30)

total_questions = len(quiz_data)
percentage = (score / total_questions) * 100

print(f"\nQuiz Finished!")
print(f"Your Final Score: {score}/{total_questions} ({percentage}%)")
# Out:
# --- Welcome to the Quiz! ---
# Your answer is Yes or No
# Do you love me?  No
# Wrong. The correct answer was Yes.
# ------------------------------
#
# Quiz Finished!
# Your Final Score: 0/1 (0.0%)
