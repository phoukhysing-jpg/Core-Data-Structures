# %%
prices = []
while True:
    uesr = input("prices of items")
    if user.lower() == "done":
        break
    try:
        price = float(user)
        prices.append(price)
    except:
        print("Invalid input, please enter a number.")
if len(prices) > 0:
    total = sum(prices)
    highest = max(prices)
    average = total / len(prices)

    print("\n----- RECEIPT -----")
    print("Items:", prices)
    print("Total cost:", round(total, 2))
    print("Most expensive item:", highest)
    print("Average price:", round(average, 2))
else:
    print("No items were added.")
